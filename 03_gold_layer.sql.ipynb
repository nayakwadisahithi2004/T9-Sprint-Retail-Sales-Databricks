-- %%
DROP TABLE IF EXISTS retail_etl.dim_customer;

CREATE TABLE retail_etl.dim_customer AS
SELECT
    CustomerID,
    CustomerName,
    Email,
    City,
    Address
FROM retail_etl.silver_customers;

-- %%
DROP TABLE IF EXISTS retail_etl.dim_product;

CREATE TABLE retail_etl.dim_product AS
SELECT
    ProductID,
    ProductName,
    Category,
    UnitPrice
FROM retail_etl.silver_products;

-- %%
DROP TABLE IF EXISTS retail_etl.dim_store;

CREATE TABLE retail_etl.dim_store AS
SELECT
    StoreID,
    StoreName,
    Region
FROM retail_etl.silver_stores;

-- %%
DROP TABLE IF EXISTS retail_etl.fact_sales;

CREATE TABLE retail_etl.fact_sales AS
SELECT
    s.TransactionID,
    s.CustomerID,
    s.ProductID,
    s.StoreID,
    s.Quantity,
    p.UnitPrice,
    s.Quantity * p.UnitPrice AS SalesAmount,
    s.TxnDate
FROM retail_etl.silver_sales s
JOIN retail_etl.dim_product p
ON s.ProductID = p.ProductID;
SELECT * FROM retail_etl.fact_sales;
